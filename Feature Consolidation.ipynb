# %% [markdown]
# ## features to be added

# %%
import pandas as pd

# %%
feature2 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/features_created_3.csv")

# %%
feature2
# Out:
#         Unnamed: 0         Id  QuestionsAsked  AnswersWritten  Upvotes  \
# 0                0       -1.0             0.0         26355.0      1.0
# 1                1        1.0            15.0           143.0   3392.0
# 2                2        2.0             7.0             5.0    161.0
# 3                3        3.0             6.0            32.0    580.0
# 4                4        4.0            11.0           167.0   2039.0
# 5                5        5.0            45.0           298.0   2315.0
# 6                6        8.0             1.0             0.0    145.0
# 7                7        9.0            18.0            40.0    554.0
# 8                8       11.0             1.0             0.0    108.0
# 9                9       13.0             8.0          1280.0   6653.0
# 10              10       16.0             1.0             9.0     18.0
# 11              11       17.0            29.0           580.0   2171.0
# ...

# %%
linked = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/final_linked.csv")

# %%
linked = linked[["so_id","gh_id"]]
linked
# Out:
#           so_id    gh_id
# 0             1   279488
# 1             2   235503
# 2             3    70469
# 3             5   113976
# 4             9   288793
# 5            11   420351
# 6            13   124434
# 7            17    28043
# 8            19   475469
# 9            20    85951
# 10           24   384782
# 11           26   261431
# 12           29   435036
# 13           32   756403
# 14           34    53154
# 15           35   482549
# 16           36   137190
# 17           37  1482204
# 18           38   299248
# 19           39   756161
# 20           40   515582
# 21           43  1128645
# 22           49  1399962
# 23           50   419927
# 24           51    16141
# 25           52   148684
# 26           56  1329237
# 27           57    12287
# 28           58    64079
# 29           60   293347
# ...         ...      ...
# 276521  1567066  3004469
# 276522  1567073   230995
# 276523  1567078  1300616
# 276524  1567081  6919221
# 276525  1567097  2513979
# ...

# %%
linked["gh_id"].value_counts()
# Out:
# 1054717    1
# 168711     1
# 3910432    1
# 2441030    1
# 2775838    1
# 2257691    1
# 680729     1
# 158488     1
# 135959     1
# 1180437    1
# 1182484    1
# 146194     1
# 380004     1
# 580654     1
# 2085551    1
# 191240     1
# 3308264    1
# 4436771    1
# 176899     1
# 174848     1
# 1923838    1
# 4014845    1
# 881403     1
# 883450     1
# 1383158    1
# 5049076    1
# 8205043    1
# 3482353    1
# 6148847    1
# 908014     1
#           ..
# 2096469    1
# 521556     1
# 515409     1
# 1561936    1
# 994639     1
# 468302     1
# 472396     1
# 7275850    1
# 464200     1
# 484678     1
# 1527107    1
# 476482     1
# 3034605    1
# 8344896    1
# 830783     1
# 1155112    1
# 298299     1
# 1895735    1
# 9357267    1
# 1373492    1
# 1363251    1
# 795950     1
# 2374957    1
# 275756     1
# 9178411    1
# 793897     1
# 87042      1
# 1044568    1
# 2376994    1
# 526337     1
# Name: gh_id, Length: 276551, dtype: int64

# %%
linked["so_id"].value_counts()
# Out:
# 528382     1
# 1100143    1
# 896736     1
# 1161376    1
# 810718     1
# 804573     1
# 294618     1
# 812761     1
# 814808     1
# 794326     1
# 1049015    1
# 265940     1
# 802514     1
# 274128     1
# 1373899    1
# 327370     1
# 1359554    1
# 900834     1
# 1529535    1
# 1555689    1
# 1001149    1
# 1003196    1
# 489147     1
# 1384237    1
# 1535672    1
# 1549546    1
# 1515190    1
# 460469     1
# 1521331    1
# 1101761    1
#           ..
# 1070484    1
# 57783      1
# 573875     1
# 1102257    1
# 532911     1
# 2474       1
# 1053097    1
# 549287     1
# 1077669    1
# 555428     1
# 541091     1
# 1071520    1
# 1157534    1
# 635293     1
# 1161628    1
# 1147291    1
# 1116920    1
# 1163021    1
# 653716     1
# 115091     1
# 643473     1
# 645520     1
# 1551476    1
# 594313     1
# 596360     1
# 1143173    1
# 1457859    1
# 606595     1
# 608642     1
# 1048576    1
# Name: so_id, Length: 276551, dtype: int64

# %%
f1 = pd.merge(left=linked,right=feature2,how='inner', left_on='so_id', right_on='Id')
f1.shape
# Out:
# (197880, 18)

# %%
f1
# Out:
#           so_id    gh_id  Unnamed: 0         Id  QuestionsAsked  \
# 0             1   279488           1        1.0            15.0
# 1             2   235503           2        2.0             7.0
# 2             3    70469           3        3.0             6.0
# 3             5   113976           5        5.0            45.0
# 4             9   288793           7        9.0            18.0
# 5            11   420351           8       11.0             1.0
# 6            13   124434           9       13.0             8.0
# 7            17    28043          11       17.0            29.0
# 8            19   475469          12       19.0             2.0
# 9            20    85951          13       20.0            21.0
# 10           24   384782          16       24.0             1.0
# 11           26   261431          18       26.0           118.0
# 12           29   435036          20       29.0            57.0
# 13           32   756403          22       32.0             2.0
# ...

# %%
f1 = f1[["so_id","QuestionsAsked", "AnswersWritten", "Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O","A","C"]]   
f1
# Out:
#           so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0             1            15.0           143.0   3392.0       90.0
# 1             2             7.0             5.0    161.0        6.0
# 2             3             6.0            32.0    580.0        6.0
# 3             5            45.0           298.0   2315.0       66.0
# 4             9            18.0            40.0    554.0        6.0
# 5            11             1.0             0.0    108.0        2.0
# 6            13             8.0          1280.0   6653.0      153.0
# 7            17            29.0           580.0   2171.0      160.0
# 8            19             2.0            12.0     29.0        2.0
# 9            20            21.0            91.0    477.0       11.0
# 10           24             1.0            13.0     24.0        0.0
# 11           26           118.0           232.0    940.0      118.0
# 12           29            57.0           434.0   3000.0       66.0
# ...

# %%
f2 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/feature_qap_edits_comments_linked.csv")

# %%
f2 = f2[["so_id", "noPosts", "noQues", "noAns", "z-score", "noPostEdits", "noComments"]]

# %%
f2
# Out:
#           so_id  noPosts  noQues   noAns    z-score  noPostEdits  noComments
# 0             1    158.0    15.0   143.0  10.183133       1112.0       495.0
# 1             2     12.0     7.0     5.0  -0.577350         25.0         6.0
# 2             3     38.0     6.0    32.0   4.217757        101.0       164.0
# 3             5    343.0    45.0   298.0  13.660716        105.0       154.0
# 4             9     58.0    18.0    40.0   2.888742          4.0        13.0
# 5            11      1.0     1.0     0.0  -1.000000          NaN         NaN
# 6            13   1288.0     8.0  1279.0  35.428786        496.0      2463.0
# 7            17    609.0    29.0   580.0  22.327647        142.0       371.0
# 8            19     14.0     2.0    12.0   2.672612          1.0         1.0
# 9            20    112.0    21.0    91.0   6.614378         62.0        89.0
# 10           24     14.0     1.0    13.0   3.207135          2.0        13.0
# ...

# %%
f1_f2 = pd.merge(left=f1,right=f2,how='outer', left_on='so_id', right_on='so_id')
f1_f2
# Out:
#             so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0             1.0            15.0           143.0   3392.0       90.0
# 1             2.0             7.0             5.0    161.0        6.0
# 2             3.0             6.0            32.0    580.0        6.0
# 3             5.0            45.0           298.0   2315.0       66.0
# 4             9.0            18.0            40.0    554.0        6.0
# 5            11.0             1.0             0.0    108.0        2.0
# 6            13.0             8.0          1280.0   6653.0      153.0
# 7            17.0            29.0           580.0   2171.0      160.0
# 8            19.0             2.0            12.0     29.0        2.0
# 9            20.0            21.0            91.0    477.0       11.0
# 10           24.0             1.0            13.0     24.0        0.0
# 11           26.0           118.0           232.0    940.0      118.0
# ...

# %%
f3=pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/user_comments_sentiment.csv")

# %%
f3
# Out:
#           so_id    gh_id  sentiment_user_comments  subjectivity_user_comments
# 0             1   279488                 0.133205                    0.392152
# 1             2   235503                 0.110833                    0.195417
# 2             3    70469                 0.309884                    0.474664
# 3             5   113976                 0.142600                    0.338181
# 4             9   288793                 0.047837                    0.321728
# 5            13   124434                 0.198769                    0.520956
# 6            17    28043                 0.080116                    0.376115
# 7            19   475469                -0.400000                    0.700000
# 8            20    85951                 0.113076                    0.383154
# 9            24   384782                 0.196800                    0.458620
# 10           26   261431                 0.076591                    0.390977
# ...

# %%
f3 =f3[["so_id", "sentiment_user_comments", "subjectivity_user_comments"]]
f3
# Out:
#           so_id  sentiment_user_comments  subjectivity_user_comments
# 0             1                 0.133205                    0.392152
# 1             2                 0.110833                    0.195417
# 2             3                 0.309884                    0.474664
# 3             5                 0.142600                    0.338181
# 4             9                 0.047837                    0.321728
# 5            13                 0.198769                    0.520956
# 6            17                 0.080116                    0.376115
# 7            19                -0.400000                    0.700000
# 8            20                 0.113076                    0.383154
# 9            24                 0.196800                    0.458620
# 10           26                 0.076591                    0.390977
# 11           29                 0.117467                    0.385766
# 12           34                 0.138779                    0.579638
# ...

# %%
f1_f2_f3 = pd.merge(left=f1_f2,right=f3,how='outer', left_on='so_id', right_on='so_id')
f1_f2_f3
# Out:
#               so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0                 1            15.0           143.0   3392.0       90.0
# 1                 2             7.0             5.0    161.0        6.0
# 2                 3             6.0            32.0    580.0        6.0
# 3                 5            45.0           298.0   2315.0       66.0
# 4                 9            18.0            40.0    554.0        6.0
# 5                11             1.0             0.0    108.0        2.0
# 6                13             8.0          1280.0   6653.0      153.0
# 7                17            29.0           580.0   2171.0      160.0
# 8                19             2.0            12.0     29.0        2.0
# 9                20            21.0            91.0    477.0       11.0
# 10               24             1.0            13.0     24.0        0.0
# 11               26           118.0           232.0    940.0      118.0
# ...

# %%
f4 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/sentiment_user_answer_posts.csv")
f4
# Out:
#           so_id    gh_id  sentimentPolarity_Ans_post  subjectivity_ans_posts
# 0             1   279488                    0.097909                0.429973
# 1             2   235503                    0.131429                0.357654
# 2             3    70469                    0.234420                0.429940
# 3             5   113976                    0.105512                0.391812
# 4             9   288793                    0.071704                0.333819
# 5            13   124434                    0.130973                0.439466
# 6            17    28043                    0.125651                0.396001
# 7            19   475469                    0.034722                0.373611
# 8            20    85951                    0.109038                0.444789
# 9            24   384782                    0.088471                0.403982
# 10           26   261431                    0.096044                0.364254
# ...

# %%
f4 =f4[["so_id","sentimentPolarity_Ans_post","subjectivity_ans_posts"]]
f4
# Out:
#           so_id  sentimentPolarity_Ans_post  subjectivity_ans_posts
# 0             1                    0.097909                0.429973
# 1             2                    0.131429                0.357654
# 2             3                    0.234420                0.429940
# 3             5                    0.105512                0.391812
# 4             9                    0.071704                0.333819
# 5            13                    0.130973                0.439466
# 6            17                    0.125651                0.396001
# 7            19                    0.034722                0.373611
# 8            20                    0.109038                0.444789
# 9            24                    0.088471                0.403982
# 10           26                    0.096044                0.364254
# 11           29                    0.117022                0.425730
# 12           32                    0.002551                0.123299
# ...

# %%
f5 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/feature_time_elapsed_linked.csv")
f5
# Out:
#         Unnamed: 0  Unnamed: 0_x    so_id    gh_id  \
# 0                0             0        1   279488
# 1                1             1        2   235503
# 2                2             2        3    70469
# 3                3             3        5   113976
# 4                4             4        9   288793
# 5                5             9       13   124434
# 6                6            10       17    28043
# 7                7            11       19   475469
# 8                8            12       20    85951
# 9                9            13       24   384782
# 10              10            14       26   261431
# 11              11            15       29   435036
# 12              12            16       32   756403
# 13              13            17       34    53154
# 14              14            18       35   482549
# 15              15            19       36   137190
# 16              16            20       37  1482204
# ...

# %%
f5 = f5[["so_id", "time_diff_sec"]]
f5
# Out:
#           so_id  time_diff_sec
# 0             1   8.495827e+05
# 1             2   2.172309e+07
# 2             3   2.956788e+06
# 3             5   4.246572e+05
# 4             9   2.990387e+06
# 5            13   9.791954e+04
# 6            17   1.983185e+05
# 7            19   8.875555e+06
# 8            20   1.061775e+06
# 9            24   9.785245e+06
# 10           26   5.379880e+05
# 11           29   2.865777e+05
# 12           32   2.905683e+03
# 13           34   1.704862e+06
# 14           35   4.457837e+05
# 15           36   1.068775e+06
# 16           37   2.669248e+06
# 17           38   2.224027e+06
# 18           39   1.718175e+06
# 19           40   1.149148e+06
# 20           43   5.009371e+06
# 21           49   1.297825e+06
# 22           50   5.544168e+05
# 23           51   6.757824e+05
# 24           52   1.096495e+05
# 25           56   3.199489e+06
# 26           57            NaN
# 27           58   2.029089e+06
# 28           60   2.264704e+05
# ...

# %%
f4_f5 = pd.merge(left=f4,right=f5,how='outer', left_on='so_id', right_on='so_id')
f4_f5
# Out:
#           so_id  sentimentPolarity_Ans_post  subjectivity_ans_posts  \
# 0             1                    0.097909                0.429973
# 1             2                    0.131429                0.357654
# 2             3                    0.234420                0.429940
# 3             5                    0.105512                0.391812
# 4             9                    0.071704                0.333819
# 5            13                    0.130973                0.439466
# 6            17                    0.125651                0.396001
# 7            19                    0.034722                0.373611
# 8            20                    0.109038                0.444789
# 9            24                    0.088471                0.403982
# 10           26                    0.096044                0.364254
# 11           29                    0.117022                0.425730
# 12           32                    0.002551                0.123299
# ...

# %%
f1_f2_f3_f4_f5 = pd.merge(left=f1_f2_f3,right=f4_f5,how='outer', left_on='so_id', right_on='so_id')
f1_f2_f3_f4_f5
# Out:
#               so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0                 1            15.0           143.0   3392.0       90.0
# 1                 2             7.0             5.0    161.0        6.0
# 2                 3             6.0            32.0    580.0        6.0
# 3                 5            45.0           298.0   2315.0       66.0
# 4                 9            18.0            40.0    554.0        6.0
# 5                11             1.0             0.0    108.0        2.0
# 6                13             8.0          1280.0   6653.0      153.0
# 7                17            29.0           580.0   2171.0      160.0
# 8                19             2.0            12.0     29.0        2.0
# 9                20            21.0            91.0    477.0       11.0
# 10               24             1.0            13.0     24.0        0.0
# 11               26           118.0           232.0    940.0      118.0
# ...

# %%
f6 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/mean_spell_comments.csv")
f6 = f6[["so_id", "spell_score"]]
f6
# Out:
#           so_id  spell_score
# 0             1     0.662626
# 1             2     0.333333
# 2             3     0.896341
# 3             5     1.396104
# 4             9     1.461538
# 5            13     1.382866
# 6            17     1.145553
# 7            19     3.000000
# 8            20     1.033708
# 9            24     3.307692
# 10           26     1.070886
# 11           29     0.774648
# 12           34     1.625000
# 13           35     1.129412
# 14           36     0.568966
# 15           37     0.910112
# 16           38     0.794872
# 17           39     1.048780
# 18           40     0.864583
# 19           43     0.706522
# 20           49     2.074074
# 21           50     0.882716
# 22           51     1.144928
# 23           56     2.012821
# 24           58     1.238938
# 25           60     2.389151
# 26           61     0.991667
# 27           65     0.000000
# 28           67     0.967682
# 29           71     1.195929
# ...         ...          ...
# ...

# %%
f7 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/mean_typo_comments.csv")
f7 = f7[["so_id", "typo_score"]]
f7
# Out:
#           so_id  typo_score
# 0             1    1.668687
# 1             2    0.166667
# 2             3    0.652439
# 3             5    1.389610
# 4             9    1.384615
# 5            13    0.894438
# 6            17    0.000000
# 7            19    0.000000
# 8            20    0.000000
# 9            24    0.000000
# 10           26    0.000000
# 11           29    0.000000
# 12           34    0.000000
# 13           35    0.000000
# 14           36    0.000000
# 15           37    0.000000
# 16           38    0.000000
# 17           39    0.000000
# 18           40    0.000000
# 19           43    0.000000
# 20           49    0.000000
# 21           50    0.000000
# 22           51    0.000000
# 23           56    0.000000
# 24           58    0.000000
# 25           60    0.000000
# 26           61    0.000000
# 27           65    0.000000
# 28           67    0.000000
# 29           71    0.000000
# ...         ...         ...
# 121248  1566017    0.000000
# ...

# %%
f6_f7 = pd.merge(left=f6,right=f7,how='outer', left_on='so_id', right_on='so_id')
f6_f7
# Out:
#           so_id  spell_score  typo_score
# 0             1     0.662626    1.668687
# 1             2     0.333333    0.166667
# 2             3     0.896341    0.652439
# 3             5     1.396104    1.389610
# 4             9     1.461538    1.384615
# 5            13     1.382866    0.894438
# 6            17     1.145553    0.000000
# 7            19     3.000000    0.000000
# 8            20     1.033708    0.000000
# 9            24     3.307692    0.000000
# 10           26     1.070886    0.000000
# 11           29     0.774648    0.000000
# 12           34     1.625000    0.000000
# 13           35     1.129412    0.000000
# 14           36     0.568966    0.000000
# 15           37     0.910112    0.000000
# 16           38     0.794872    0.000000
# 17           39     1.048780    0.000000
# 18           40     0.864583    0.000000
# 19           43     0.706522    0.000000
# 20           49     2.074074    0.000000
# 21           50     0.882716    0.000000
# ...

# %%
f1_f2_f3_f4_f5_f6_f7 = pd.merge(left=f1_f2_f3_f4_f5,right=f6_f7,how='outer', left_on='so_id', right_on='so_id')
f1_f2_f3_f4_f5_f6_f7
# Out:
#               so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0                 1            15.0           143.0   3392.0       90.0
# 1                 2             7.0             5.0    161.0        6.0
# 2                 3             6.0            32.0    580.0        6.0
# 3                 5            45.0           298.0   2315.0       66.0
# 4                 9            18.0            40.0    554.0        6.0
# 5                11             1.0             0.0    108.0        2.0
# 6                13             8.0          1280.0   6653.0      153.0
# 7                17            29.0           580.0   2171.0      160.0
# 8                19             2.0            12.0     29.0        2.0
# 9                20            21.0            91.0    477.0       11.0
# 10               24             1.0            13.0     24.0        0.0
# 11               26           118.0           232.0    940.0      118.0
# ...

# %%
f8 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/posts_mean_spelling.csv")
f8 = f8[["so_id", "spell_score"]]
f8
# Out:
#           so_id  spell_score
# 0             1     4.658228
# 1             2     5.333333
# 2             3     2.447368
# 3             5     3.775510
# 4             9     5.034483
# 5            11     0.000000
# 6            13     1.823758
# 7            17     1.945813
# 8            19     1.214286
# 9            20     3.169643
# 10           24     6.000000
# 11           26     2.214286
# 12           29     2.036660
# 13           32     2.400000
# 14           34     2.271429
# 15           35     2.876712
# 16           36     1.769912
# 17           37     2.611111
# 18           38     3.212766
# 19           39     3.600000
# 20           40     2.180180
# 21           43     5.694444
# 22           49     3.439024
# 23           50     2.090909
# 24           51     3.484716
# 25           52     2.818182
# 26           56     2.261538
# 27           57     8.000000
# 28           58     4.186441
# 29           60     3.805808
# ...         ...          ...
# ...

# %%
f9 =pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/posts_mean_typo.csv")
f9 = f9[["so_id", "typo_score"]]
f9
# Out:
#           so_id  typo_score
# 0             1    0.746835
# 1             2    0.000000
# 2             3    0.000000
# 3             5    0.000000
# 4             9    0.000000
# 5            11    0.000000
# 6            13    0.000000
# 7            17    0.000000
# 8            19    0.000000
# 9            20    0.000000
# 10           24    0.000000
# 11           26    0.000000
# 12           29    0.000000
# 13           32    0.000000
# 14           34    0.000000
# 15           35    0.000000
# 16           36    0.000000
# 17           37    0.000000
# 18           38    0.000000
# 19           39    0.000000
# 20           40    0.000000
# 21           43    0.000000
# 22           49    0.000000
# 23           50    0.000000
# 24           51    0.000000
# 25           52    0.000000
# 26           56    0.000000
# 27           57    0.000000
# 28           58    0.000000
# 29           60    0.000000
# ...         ...         ...
# 185449  1566703    0.000000
# ...

# %%
f8_f9 = pd.merge(left=f8,right=f9,how='outer', left_on='so_id', right_on='so_id')
f8_f9
# Out:
#           so_id  spell_score  typo_score
# 0             1     4.658228    0.746835
# 1             2     5.333333    0.000000
# 2             3     2.447368    0.000000
# 3             5     3.775510    0.000000
# 4             9     5.034483    0.000000
# 5            11     0.000000    0.000000
# 6            13     1.823758    0.000000
# 7            17     1.945813    0.000000
# 8            19     1.214286    0.000000
# 9            20     3.169643    0.000000
# 10           24     6.000000    0.000000
# 11           26     2.214286    0.000000
# 12           29     2.036660    0.000000
# 13           32     2.400000    0.000000
# 14           34     2.271429    0.000000
# 15           35     2.876712    0.000000
# 16           36     1.769912    0.000000
# 17           37     2.611111    0.000000
# 18           38     3.212766    0.000000
# 19           39     3.600000    0.000000
# 20           40     2.180180    0.000000
# 21           43     5.694444    0.000000
# ...

# %%
f10 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/questionClarity.csv")
f10 = f10[["so_id", "sentiment_polarity", "sentiment_subjectivity"]]
f10
# Out:
#          so_id  sentiment_polarity  sentiment_subjectivity
# 0            1            0.871563                3.645775
# 1            2            0.400000                0.625000
# 2            3            0.108333                0.408333
# 3            5            0.240059                0.963859
# 4            9            0.188481                0.548949
# 5           11            0.000000                0.000000
# 6           13            2.184646                5.021786
# 7           17            0.810826                3.038075
# 8           20            0.064796                0.824887
# 9           26            0.270520                1.279288
# 10          29            0.575321                1.340995
# 11          34           -0.066045                0.346232
# 12          35            0.047619                0.172619
# 13          36           -0.029315                0.696280
# 14          37            0.197950                1.343817
# ...

# %%
f10.columns = ["so_id", "questionClarity_sentiment", "questionClarity_subjectivity"]
f10
# Out:
#          so_id  questionClarity_sentiment  questionClarity_subjectivity
# 0            1                   0.871563                      3.645775
# 1            2                   0.400000                      0.625000
# 2            3                   0.108333                      0.408333
# 3            5                   0.240059                      0.963859
# 4            9                   0.188481                      0.548949
# 5           11                   0.000000                      0.000000
# 6           13                   2.184646                      5.021786
# 7           17                   0.810826                      3.038075
# 8           20                   0.064796                      0.824887
# 9           26                   0.270520                      1.279288
# 10          29                   0.575321                      1.340995
# 11          34                  -0.066045                      0.346232
# ...

# %%
f8_f9_f10 = pd.merge(left=f8_f9,right=f10,how='outer', left_on='so_id', right_on='so_id')
f8_f9_f10
# Out:
#           so_id  spell_score  typo_score  questionClarity_sentiment  \
# 0             1     4.658228    0.746835                   0.871563
# 1             2     5.333333    0.000000                   0.400000
# 2             3     2.447368    0.000000                   0.108333
# 3             5     3.775510    0.000000                   0.240059
# 4             9     5.034483    0.000000                   0.188481
# 5            11     0.000000    0.000000                   0.000000
# 6            13     1.823758    0.000000                   2.184646
# 7            17     1.945813    0.000000                   0.810826
# 8            19     1.214286    0.000000                        NaN
# 9            20     3.169643    0.000000                   0.064796
# 10           24     6.000000    0.000000                        NaN
# 11           26     2.214286    0.000000                   0.270520
# 12           29     2.036660    0.000000                   0.575321
# ...

# %%
f1_f2_f3_f4_f5_f6_f7_f8_f9_f10 = pd.merge(left=f1_f2_f3_f4_f5_f6_f7,right=f8_f9_f10,how='outer', left_on='so_id', right_on='so_id')
f1_f2_f3_f4_f5_f6_f7_f8_f9_f10
# Out:
#               so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0                 1            15.0           143.0   3392.0       90.0
# 1                 2             7.0             5.0    161.0        6.0
# 2                 3             6.0            32.0    580.0        6.0
# 3                 5            45.0           298.0   2315.0       66.0
# 4                 9            18.0            40.0    554.0        6.0
# 5                11             1.0             0.0    108.0        2.0
# 6                13             8.0          1280.0   6653.0      153.0
# 7                17            29.0           580.0   2171.0      160.0
# 8                19             2.0            12.0     29.0        2.0
# 9                20            21.0            91.0    477.0       11.0
# 10               24             1.0            13.0     24.0        0.0
# 11               26           118.0           232.0    940.0      118.0
# ...

# %%
f11 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/answerQuality.csv")
f11 = f11[["so_id", "sentiment_polarity", "sentiment_subjectivity"]]
f11
# Out:
#          so_id  sentiment_polarity  sentiment_subjectivity
# 0            1            0.362579                1.091097
# 1            2           -0.492500                1.257083
# 2            3            0.396555                1.088019
# 3            5            0.342270                0.918839
# 4            9            0.164661                0.615089
# 5           13            0.423394                1.341532
# 6           17            0.218376                0.951444
# 7           19            0.134167                0.486667
# 8           20            0.451395                1.096176
# 9           24            0.698764                1.795385
# 10          26            0.289128                0.945022
# 11          29            0.325858                0.993341
# 12          34            0.347342                0.913963
# 13          35            0.146136                0.806308
# 14          36            0.213663                0.937431
# ...

# %%
f11.columns = ["so_id", "answerQuality_sentiment", "answerQuality_subjectivity"]
f11
# Out:
#          so_id  answerQuality_sentiment  answerQuality_subjectivity
# 0            1                 0.362579                    1.091097
# 1            2                -0.492500                    1.257083
# 2            3                 0.396555                    1.088019
# 3            5                 0.342270                    0.918839
# 4            9                 0.164661                    0.615089
# 5           13                 0.423394                    1.341532
# 6           17                 0.218376                    0.951444
# 7           19                 0.134167                    0.486667
# 8           20                 0.451395                    1.096176
# 9           24                 0.698764                    1.795385
# 10          26                 0.289128                    0.945022
# 11          29                 0.325858                    0.993341
# 12          34                 0.347342                    0.913963
# ...

# %%
f12 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/feature_so_ratio_updown_votes.csv")
f12
# Out:
#        Unnamed: 0      so_id    gh_id  NoOfUpvotedAnswers  \
# 0               0        1.0   279488               157.0
# 1               1        2.0   235503                 8.0
# 2               2        3.0    70469                32.0
# 3               3        5.0   113976               267.0
# 4               4        9.0   288793                41.0
# 5               6       13.0   124434              1203.0
# 6               7       17.0    28043               424.0
# 7               8       19.0   475469                 8.0
# 8               9       20.0    85951                81.0
# 9              10       24.0   384782                 8.0
# 10             11       26.0   261431               133.0
# 11             12       29.0   435036               431.0
# 12             13       32.0   756403                 1.0
# 13             14       34.0    53154                66.0
# 14             15       35.0   482549               173.0
# ...

# %%
f12 = f12[["so_id", "ratio"]]
f12
# Out:
#            so_id     ratio
# 0            1.0  0.025478
# 1            2.0  0.000000
# 2            3.0  0.125000
# 3            5.0  0.078652
# 4            9.0  0.000000
# 5           13.0  0.030756
# 6           17.0  0.183962
# 7           19.0  0.000000
# 8           20.0  0.024691
# 9           24.0  0.000000
# 10          26.0  0.360902
# 11          29.0  0.018561
# 12          32.0  2.000000
# 13          34.0  0.090909
# 14          35.0  0.069364
# 15          36.0  0.108434
# 16          37.0  0.055556
# 17          38.0  0.111111
# 18          39.0  0.065217
# 19          40.0  0.089286
# 20          43.0  0.000000
# 21          49.0  0.026667
# 22          50.0  0.245455
# 23          51.0  0.060606
# 24          52.0  0.100000
# 25          56.0  0.000000
# 26          58.0  0.040816
# 27          60.0  0.024664
# 28          61.0  0.122222
# 29          65.0  0.100000
# ...          ...       ...
# 93896  1561533.0  0.000000
# 93897  1561588.0  0.000000
# ...

# %%
f12.columns = ["so_id", "updownRatio"]
f12
# Out:
#            so_id  updownRatio
# 0            1.0     0.025478
# 1            2.0     0.000000
# 2            3.0     0.125000
# 3            5.0     0.078652
# 4            9.0     0.000000
# 5           13.0     0.030756
# 6           17.0     0.183962
# 7           19.0     0.000000
# 8           20.0     0.024691
# 9           24.0     0.000000
# 10          26.0     0.360902
# 11          29.0     0.018561
# 12          32.0     2.000000
# 13          34.0     0.090909
# 14          35.0     0.069364
# 15          36.0     0.108434
# 16          37.0     0.055556
# 17          38.0     0.111111
# 18          39.0     0.065217
# 19          40.0     0.089286
# 20          43.0     0.000000
# 21          49.0     0.026667
# 22          50.0     0.245455
# 23          51.0     0.060606
# 24          52.0     0.100000
# 25          56.0     0.000000
# 26          58.0     0.040816
# 27          60.0     0.024664
# 28          61.0     0.122222
# 29          65.0     0.100000
# ...

# %%
f11_f12 = pd.merge(left=f11,right=f12,how='outer', left_on='so_id', right_on='so_id')
f11_f12
# Out:
#             so_id  answerQuality_sentiment  answerQuality_subjectivity  \
# 0             1.0                 0.362579                    1.091097
# 1             2.0                -0.492500                    1.257083
# 2             3.0                 0.396555                    1.088019
# 3             5.0                 0.342270                    0.918839
# 4             9.0                 0.164661                    0.615089
# 5            13.0                 0.423394                    1.341532
# 6            17.0                 0.218376                    0.951444
# 7            19.0                 0.134167                    0.486667
# 8            20.0                 0.451395                    1.096176
# 9            24.0                 0.698764                    1.795385
# 10           26.0                 0.289128                    0.945022
# 11           29.0                 0.325858                    0.993341
# ...

# %%
f1_f2_f3_f4_f5_f6_f7_f8_f9_f10_f11_f12 = pd.merge(left=f1_f2_f3_f4_f5_f6_f7_f8_f9_f10,right=f11_f12,how='outer', left_on='so_id', right_on='so_id')
f1_f2_f3_f4_f5_f6_f7_f8_f9_f10_f11_f12
# Out:
#               so_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0                 1            15.0           143.0   3392.0       90.0
# 1                 2             7.0             5.0    161.0        6.0
# 2                 3             6.0            32.0    580.0        6.0
# 3                 5            45.0           298.0   2315.0       66.0
# 4                 9            18.0            40.0    554.0        6.0
# 5                11             1.0             0.0    108.0        2.0
# 6                13             8.0          1280.0   6653.0      153.0
# 7                17            29.0           580.0   2171.0      160.0
# 8                19             2.0            12.0     29.0        2.0
# 9                20            21.0            91.0    477.0       11.0
# 10               24             1.0            13.0     24.0        0.0
# 11               26           118.0           232.0    940.0      118.0
# ...

# %%
so_features = pd.merge(left=linked,right=f1_f2_f3_f4_f5_f6_f7_f8_f9_f10_f11_f12,how='inner', left_on='so_id', right_on='so_id')
so_features
# Out:
#           so_id    gh_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0             1   279488            15.0           143.0   3392.0       90.0
# 1             2   235503             7.0             5.0    161.0        6.0
# 2             3    70469             6.0            32.0    580.0        6.0
# 3             5   113976            45.0           298.0   2315.0       66.0
# 4             9   288793            18.0            40.0    554.0        6.0
# 5            11   420351             1.0             0.0    108.0        2.0
# 6            13   124434             8.0          1280.0   6653.0      153.0
# 7            17    28043            29.0           580.0   2171.0      160.0
# 8            19   475469             2.0            12.0     29.0        2.0
# 9            20    85951            21.0            91.0    477.0       11.0
# 10           24   384782             1.0            13.0     24.0        0.0
# ...

# %% [markdown]
# ### -------------------------------------

# %% [markdown]
# ### GH Features

# %%
g1 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/gh_follower_followee_ratio.csv")
g1
# Out:
#         Unnamed: 0    so_id    gh_id                          mailHash  \
# 0                0        2   235503  b437f461b3fd27387c5d8ab47a293d35
# 1                1        5   113976  1c494896dd56e0e27253156c28f1dfb9
# 2                2        9   288793  23c1e2063688620b75b248e08c0d5c24
# 3                3       13   124434  729442eea8d8548842a6e0947e333c7b
# 4                4       17    28043  42893555ea66c988b51c9167a650d849
# 5                5       20    85951  1f0b00b8853cf0311888bb3ed2a77ebc
# 6                6       24   384782  b51e14bfee5fd2f1d63c8e2b0ff2f2bb
# 7                7       26   261431  f878a55e08bacee0af48852c29a02dc7
# 8                8       29   435036  f4f4b5a6f27f72b32d42463b1a25e0df
# 9                9       32   756403  399ecfe1915ddb853a0421afeccbfa02
# 10              10       34    53154  6f448664cd294829b9ed0cd356f91cb1
# 11              11       35   482549  c03ec7268e3c266e10dff18e61a2498f
# ...

# %%
g1 = g1[["gh_id", "f_ratio"]]
g1
# Out:
#           gh_id   f_ratio
# 0        235503  0.500000
# 1        113976  0.151515
# 2        288793  0.230769
# 3        124434  1.839286
# 4         28043  0.750000
# 5         85951  0.011189
# 6        384782  1.272727
# 7        261431  1.375000
# 8        435036  0.250000
# 9        756403  0.666667
# 10        53154  0.003300
# 11       482549  0.500000
# 12       137190  1.750000
# 13      1482204  1.000000
# 14       756161  4.846154
# 15       515582  1.000000
# 16      1399962  1.000000
# 17       419927  0.117647
# 18        16141  0.100000
# 19       148684  3.478261
# 20        12287  1.708333
# 21        64079  1.434783
# 22       293347  0.250000
# 23        93612  0.363636
# 24       576241  0.058824
# 25      1337731  3.166667
# 26         2330  2.863636
# 27       222151  1.222222
# 28      1261790  2.666667
# 29       725971  0.333333
# ...         ...       ...
# 107070    88698  0.800000
# 107071    69953  1.000000
# 107072    38817  7.500000
# ...

# %%
g2 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/gh_projects_comments.csv")
g2
# Out:
#         Unnamed: 0  so_id    gh_id  noProjects  Unnamed: 0.1  \
# 0                0    1.0   279488         5.0        7837.0
# 1                1    2.0   235503         1.0           NaN
# 2                2    3.0    70469         5.0           NaN
# 3                3    5.0   113976        39.0       43321.0
# 4                4    9.0   288793         8.0           NaN
# 5                5   13.0   124434         9.0           NaN
# 6                6   17.0    28043        24.0       12410.0
# 7                7   20.0    85951        22.0       34008.0
# 8                8   24.0   384782        33.0           NaN
# 9                9   26.0   261431         6.0       47324.0
# 10              10   29.0   435036        16.0       17961.0
# 11              11   32.0   756403         7.0           NaN
# 12              12   34.0    53154        42.0       22187.0
# 13              13   35.0   482549        13.0           NaN
# ...

# %%
g2 = g2[["gh_id", "noProjects", "NoOfCommitComments"]]
g2
# Out:
#           gh_id  noProjects  NoOfCommitComments
# 0        279488         5.0                75.0
# 1        235503         1.0                 NaN
# 2         70469         5.0                 NaN
# 3        113976        39.0                 1.0
# 4        288793         8.0                 NaN
# 5        124434         9.0                 NaN
# 6         28043        24.0                15.0
# 7         85951        22.0                40.0
# 8        384782        33.0                 NaN
# 9        261431         6.0                28.0
# 10       435036        16.0                 1.0
# 11       756403         7.0                 NaN
# 12        53154        42.0                34.0
# 13       482549        13.0                 NaN
# 14       137190         7.0                 NaN
# 15      1482204         3.0                 NaN
# 16       756161         2.0                 1.0
# 17       515582        30.0               189.0
# 18      1128645         3.0                 NaN
# ...

# %%
g3 = pd.read_csv("/Users/aishwaryagupta/Desktop/Btp feature creation_Latest_27thApril/features created/noProjects_members.csv")
g3
# Out:
#         Unnamed: 0  user_id  noProjects_members
# 0                0        2                  38
# 1                1        4                  21
# 2                2        5                  19
# 3                3        9                  48
# 4                4       10                  82
# 5                5       12                  39
# 6                6       19                  27
# 7                7       26                  16
# 8                8       27                  39
# 9                9       37                   3
# 10              10       47                  58
# 11              11       52                   2
# 12              12       53                  13
# 13              13       54                   9
# 14              14       57                  16
# 15              15       60                   1
# 16              16       71                  11
# 17              17       73                  15
# 18              18       78                   8
# ...

# %%
g3 = g3[["user_id", "noProjects_members"]]
g3
# Out:
#         user_id  noProjects_members
# 0             2                  38
# 1             4                  21
# 2             5                  19
# 3             9                  48
# 4            10                  82
# 5            12                  39
# 6            19                  27
# 7            26                  16
# 8            27                  39
# 9            37                   3
# 10           47                  58
# 11           52                   2
# 12           53                  13
# 13           54                   9
# 14           57                  16
# 15           60                   1
# 16           71                  11
# 17           73                  15
# 18           78                   8
# 19           81                  21
# 20           87                   6
# 21           89                  21
# 22           91                   5
# 23           92                  40
# 24           93                  32
# ...

# %%
g3.columns = ["gh_id", "noProjects_members"]
g3
# Out:
#           gh_id  noProjects_members
# 0             2                  38
# 1             4                  21
# 2             5                  19
# 3             9                  48
# 4            10                  82
# 5            12                  39
# 6            19                  27
# 7            26                  16
# 8            27                  39
# 9            37                   3
# 10           47                  58
# 11           52                   2
# 12           53                  13
# 13           54                   9
# 14           57                  16
# 15           60                   1
# 16           71                  11
# 17           73                  15
# 18           78                   8
# 19           81                  21
# 20           87                   6
# 21           89                  21
# 22           91                   5
# 23           92                  40
# 24           93                  32
# ...

# %%
g1_g2 = pd.merge(left=g1,right=g2,how='outer', left_on='gh_id', right_on='gh_id')
g1_g2
# Out:
#           gh_id   f_ratio  noProjects  NoOfCommitComments
# 0        235503  0.500000         1.0                 NaN
# 1        113976  0.151515        39.0                 1.0
# 2        288793  0.230769         8.0                 NaN
# 3        124434  1.839286         9.0                 NaN
# 4         28043  0.750000        24.0                15.0
# 5         85951  0.011189        22.0                40.0
# 6        384782  1.272727        33.0                 NaN
# 7        261431  1.375000         6.0                28.0
# 8        435036  0.250000        16.0                 1.0
# 9        756403  0.666667         7.0                 NaN
# 10        53154  0.003300        42.0                34.0
# 11       482549  0.500000        13.0                 NaN
# 12       137190  1.750000         7.0                 NaN
# 13      1482204  1.000000         3.0                 NaN
# 14       756161  4.846154         2.0                 1.0
# ...

# %%
g1_g2_g3 = pd.merge(left=g1_g2,right=g3,how='outer', left_on='gh_id', right_on='gh_id')
g1_g2_g3
# Out:
#           gh_id   f_ratio  noProjects  NoOfCommitComments  noProjects_members
# 0        235503  0.500000         1.0                 NaN                 1.0
# 1        113976  0.151515        39.0                 1.0               112.0
# 2        288793  0.230769         8.0                 NaN                 2.0
# 3        124434  1.839286         9.0                 NaN                 5.0
# 4         28043  0.750000        24.0                15.0                17.0
# 5         85951  0.011189        22.0                40.0               122.0
# 6        384782  1.272727        33.0                 NaN                15.0
# 7        261431  1.375000         6.0                28.0                 5.0
# 8        435036  0.250000        16.0                 1.0                 4.0
# 9        756403  0.666667         7.0                 NaN                 1.0
# 10        53154  0.003300        42.0                34.0                29.0
# ...

# %%
g1_g2_g3["gh_id"].value_counts
# Out:
# <bound method Series.value_counts of 0          235503
# 1          113976
# 2          288793
# 3          124434
# 4           28043
# 5           85951
# 6          384782
# 7          261431
# 8          435036
# 9          756403
# 10          53154
# 11         482549
# 12         137190
# 13        1482204
# 14         756161
# 15         515582
# 16        1399962
# 17         419927
# 18          16141
# 19         148684
# 20          12287
# 21          64079
# 22         293347
# 23          93612
# 24         576241
# 25        1337731
# 26           2330
# 27         222151
# 28        1261790
# 29         725971
#            ...
# 236494    9292236
# 236495    9294231
# 236496    9294688
# 236497    9295300
# 236498    9295782
# 236499    9296047
# 236500    9296257
# 236501    9297056
# 236502    9298064
# 236503    9298224
# 236504    9299983
# 236505    9300173
# 236506    9301405
# 236507    9301485
# 236508    9301562
# 236509    9302680
# 236510    9303611
# ...

# %%
features = pd.merge(left=so_features,right=g1_g2_g3,how='outer', left_on='gh_id', right_on='gh_id')
features
# Out:
#        so_id    gh_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0          1   279488            15.0           143.0   3392.0       90.0
# 1          2   235503             7.0             5.0    161.0        6.0
# 2          3    70469             6.0            32.0    580.0        6.0
# 3          5   113976            45.0           298.0   2315.0       66.0
# 4          9   288793            18.0            40.0    554.0        6.0
# 5         11   420351             1.0             0.0    108.0        2.0
# 6         13   124434             8.0          1280.0   6653.0      153.0
# 7         17    28043            29.0           580.0   2171.0      160.0
# 8         19   475469             2.0            12.0     29.0        2.0
# 9         20    85951            21.0            91.0    477.0       11.0
# 10        24   384782             1.0            13.0     24.0        0.0
# 11        26   261431           118.0           232.0    940.0      118.0
# ...

# %%
f= features

# %%
del features["so_id"]

# %%
features1 = pd.merge(left=linked,right=features,how='inner', left_on='gh_id', right_on='gh_id')
features1
# Out:
#           so_id    gh_id  QuestionsAsked  AnswersWritten  Upvotes  Downvotes  \
# 0             1   279488            15.0           143.0   3392.0       90.0
# 1             2   235503             7.0             5.0    161.0        6.0
# 2             3    70469             6.0            32.0    580.0        6.0
# 3             5   113976            45.0           298.0   2315.0       66.0
# 4             9   288793            18.0            40.0    554.0        6.0
# 5            11   420351             1.0             0.0    108.0        2.0
# 6            13   124434             8.0          1280.0   6653.0      153.0
# 7            17    28043            29.0           580.0   2171.0      160.0
# 8            19   475469             2.0            12.0     29.0        2.0
# 9            20    85951            21.0            91.0    477.0       11.0
# 10           24   384782             1.0            13.0     24.0        0.0
# ...

# %%
features1.to_csv('FINAL_FEATURES.csv')

# %% [markdown]
# --------------------------------- End of File--------------------------------------

# %%
df = features1

# %%
df.shape
# Out:
# (263134, 37)

# %%
df.isnull().sum()
# Out:
# so_id                                0
# gh_id                                0
# QuestionsAsked                   77655
# AnswersWritten                   77655
# Upvotes                          77655
# Downvotes                        77655
# NoOfUpvotedAnswers               77655
# NoOfDownvotedAnswers             77655
# N                                65254
# E                                65254
# O                                65254
# A                                65254
# C                                65254
# noPosts                          77655
# noQues                           77655
# noAns                            77655
# z-score                          77655
# noPostEdits                     179934
# noComments                      141856
# sentiment_user_comments         141856
# subjectivity_user_comments      141856
# sentimentPolarity_Ans_post      133281
# subjectivity_ans_posts          133281
# time_diff_sec                   180396
# ...

# %% [markdown]
# ## old features reduce--------------------------------------------------------------

# %%
df.shape
# Out:
# (263134, 35)

# %%
df.isnull().sum()
# Out:
# so_id                                0
# gh_id                                0
# Upvotes                          77655
# Downvotes                        77655
# NoOfUpvotedAnswers               77655
# NoOfDownvotedAnswers             77655
# N                                77091
# E                                77091
# O                                77091
# A                                77091
# C                                77091
# noPosts                          77655
# noQues                           77655
# noAns                            77655
# z-score                          77655
# noPostEdits                     179934
# noComments                      141856
# sentiment_user_comments         141856
# subjectivity_user_comments      141856
# sentimentPolarity_Ans_post      133281
# subjectivity_ans_posts          133281
# time_diff_sec                   180396
# spell_comments_so               141856
# typo_comments_so                141856
# ...

# %%
df.isnull().sum().sum()
# Out:
# 3876714L

# %%
df.isnull().values.sum()
# Out:
# 3876714

# %%
263134*33
# Out:
# 8683422

# %%
df.shape[1] - df.count(axis=1)
# Out:
# 0          1
# 1          1
# 2          2
# 3          0
# 4          1
# 5         16
# 6          1
# 7          0
# 8          6
# 9          0
# 10         3
# 11         0
# 12         0
# 13        11
# 14         0
# 15         1
# 16         1
# 17         1
# 18         4
# 19         0
# 20         0
# 21         2
# 22         2
# 23         1
# 24         0
# 25         5
# 26         3
# 27        13
# 28         0
# 29         3
#           ..
# 263104    17
# 263105    13
# 263106    32
# 263107    32
# 263108    11
# 263109    31
# 263110    17
# 263111    31
# 263112    31
# 263113    30
# 263114    31
# 263115    31
# 263116    30
# 263117    29
# 263118    32
# 263119    30
# 263120    12
# 263121    32
# 263122    30
# 263123    31
# 263124    29
# 263125    15
# 263126    31
# 263127    32
# 263128    30
# 263129    32
# 263130    32
# 263131    29
# 263132    30
# 263133    16
# Length: 263134, dtype: int64

# %%
df.count()
# Out:
# so_id                           263134
# gh_id                           263134
# Upvotes                         185479
# Downvotes                       185479
# NoOfUpvotedAnswers              185479
# NoOfDownvotedAnswers            185479
# N                               186043
# E                               186043
# O                               186043
# A                               186043
# C                               186043
# noPosts                         185479
# noQues                          185479
# noAns                           185479
# z-score                         185479
# noPostEdits                      83200
# noComments                      121278
# sentiment_user_comments         121278
# subjectivity_user_comments      121278
# sentimentPolarity_Ans_post      129853
# subjectivity_ans_posts          129853
# time_diff_sec                    82738
# spell_comments_so               121278
# typo_comments_so                121278
# ...

# %%
float(18547900)/263134
# Out:
# 70.48842034856764

# %%
float(12127800)/263134
# Out:
# 46.089824956106014

# %%
def get_percentage_missing(series):
    num = series.isnull().sum()
    den = len(series)
    return num/den

df_with_any_null_values = df[df.columns[df.isnull().any()].tolist()]

get_percentage_missing(df_with_any_null_values)
# Out:
# Upvotes                         0.295116
# Downvotes                       0.295116
# NoOfUpvotedAnswers              0.295116
# NoOfDownvotedAnswers            0.295116
# N                               0.292972
# E                               0.292972
# O                               0.292972
# A                               0.292972
# C                               0.292972
# noPosts                         0.295116
# noQues                          0.295116
# noAns                           0.295116
# z-score                         0.295116
# noPostEdits                     0.683811
# noComments                      0.539102
# sentiment_user_comments         0.539102
# subjectivity_user_comments      0.539102
# sentimentPolarity_Ans_post      0.506514
# subjectivity_ans_posts          0.506514
# time_diff_sec                   0.685567
# spell_comments_so               0.539102
# typo_comments_so                0.539102
# spell_posts                     0.295116
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263134 entries, 0 to 263133
# Data columns (total 35 columns):
# so_id                           263134 non-null object
# gh_id                           263134 non-null int64
# Upvotes                         185479 non-null float64
# Downvotes                       185479 non-null float64
# NoOfUpvotedAnswers              185479 non-null float64
# NoOfDownvotedAnswers            185479 non-null float64
# N                               186043 non-null float64
# E                               186043 non-null float64
# O                               186043 non-null float64
# A                               186043 non-null float64
# C                               186043 non-null float64
# noPosts                         185479 non-null float64
# noQues                          185479 non-null float64
# noAns                           185479 non-null float64
# z-score                         185479 non-null float64
# ...

# %%
df2 = df1[df1['N'].notnull()]

# %%
df1= df

# %%
df2
# Out:
#           so_id    gh_id  Upvotes  Downvotes  NoOfUpvotedAnswers  \
# 0             1   279488   3392.0       90.0               157.0
# 1             2   235503    161.0        6.0                 8.0
# 2             3    70469    580.0        6.0                32.0
# 3             5   113976   2315.0       66.0               267.0
# 4             9   288793    554.0        6.0                41.0
# 5            11   420351    108.0        2.0                 0.0
# 6            13   124434   6653.0      153.0              1203.0
# 7            17    28043   2171.0      160.0               424.0
# 8            19   475469     29.0        2.0                 8.0
# 9            20    85951    477.0       11.0                81.0
# 10           24   384782     24.0        0.0                 8.0
# 11           26   261431    940.0      118.0               133.0
# 12           29   435036   3000.0       66.0               431.0
# ...

# %%
df3 = df2[df2['sentiment_user_comments'].notnull()]

# %%
df3.shape
# Out:
# (121278, 35)

# %%
df4 = df3[df3['sentimentPolarity_Ans_post'].notnull()]
df4.shape
# Out:
# (85166, 35)

# %%
df5 = df4[df4['questionClarity_sentiment'].notnull()]
df5.shape
# Out:
# (58566, 35)

# %%
df6 = df5[df5['answerQuality_sentiment'].notnull()]
df6.shape
# Out:
# (44624, 35)

# %%
df6.isnull().sum()
# Out:
# so_id                               0
# gh_id                               0
# Upvotes                             0
# Downvotes                           0
# NoOfUpvotedAnswers                  0
# NoOfDownvotedAnswers                0
# N                                   0
# E                                   0
# O                                   0
# A                                   0
# C                                   0
# noPosts                             0
# noQues                              0
# noAns                               0
# z-score                             0
# noPostEdits                      5631
# noComments                          0
# sentiment_user_comments             0
# subjectivity_user_comments          0
# sentimentPolarity_Ans_post          0
# subjectivity_ans_posts              0
# time_diff_sec                    2636
# spell_comments_so                   0
# typo_comments_so                    0
# spell_posts                         0
# ...

# %%
df7 = df6

# %%
df7["noProjects"].fillna(0, inplace=True)
# Out:
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df7["f_ratio"].fillna(0, inplace=True)

# %%
df7["NoOfCommitComments"].fillna(0, inplace=True)

# %%
df7["noProjects_members"].fillna(0, inplace=True)

# %%
columns = ['noPostEdits']
df7.drop(columns, inplace=True, axis=1)
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df7.describe()
# Out:
#               gh_id        Upvotes     Downvotes  NoOfUpvotedAnswers  \
# count  4.462400e+04   44624.000000  44624.000000        44624.000000
# mean   1.369229e+06     151.529244      4.759927           35.401466
# std    1.891233e+06     901.506500     16.422597          193.044805
# min    5.000000e+00       0.000000      0.000000            0.000000
# 25%    1.851662e+05      11.000000      0.000000            2.000000
# 50%    6.058650e+05      32.000000      1.000000            6.000000
# 75%    1.672734e+06     101.000000      4.000000           22.000000
# max    9.523728e+06  134961.000000   1107.000000        21505.000000
#
#        NoOfDownvotedAnswers             N             E             O  \
# count          44624.000000  44624.000000  44624.000000  44624.000000
# mean               2.061223      3.227690      1.042512     -7.986434
# std                7.106003      1.366027      1.255565      2.293303
# ...

# %%
mean_updownRatio = 0.104227

# %%
df7["updownRatio"].mean()
# Out:
# 0.10422707276059148

# %%
df7["time_diff_sec"].mean()
# Out:
# 4512472.132004834

# %%
df7["time_diff_sec"].max()
# Out:
# 105302216.68700001

# %%
df7["time_diff_sec"].min()
# Out:
# 181.24599999999998

# %%
df7["time_diff_sec"].fillna(4512472.132004834, inplace=True)

# %%
df7["updownRatio"].fillna(0.10422707276059148, inplace=True)

# %%
df7.isnull().sum()
# Out:
# so_id                           0
# gh_id                           0
# Upvotes                         0
# Downvotes                       0
# NoOfUpvotedAnswers              0
# NoOfDownvotedAnswers            0
# N                               0
# E                               0
# O                               0
# A                               0
# C                               0
# noPosts                         0
# noQues                          0
# noAns                           0
# z-score                         0
# noComments                      0
# sentiment_user_comments         0
# subjectivity_user_comments      0
# sentimentPolarity_Ans_post      0
# subjectivity_ans_posts          0
# time_diff_sec                   0
# spell_comments_so               0
# typo_comments_so                0
# spell_posts                     0
# typo_posts                      0
# questionClarity_sentiment       0
# questionClarity_subjectivity    0
# ...

# %%
df7.to_csv("df_modellingDone.csv")

# %%
df7[["Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O", "A", "C", "noPosts", "noQues", "noAns", "z-score", "noComments", "sentiment_user_comments", "subjectivity_user_comments", "sentimentPolarity_Ans_post", "subjectivity_ans_posts", "time_diff_sec", "spell_comments_so", "typo_comments_so", "spell_posts", "typo_posts", "questionClarity_sentiment", "questionClarity_subjectivity", "answerQuality_sentiment", "answerQuality_subjectivity", "updownRatio", "f_ratio", "noProjects", "NoOfCommitComments", "noProjects_members" ]]

# %% [markdown]
# ## Feature standardization

# %%
from sklearn import preprocessing

std_scale = preprocessing.StandardScaler().fit(df7[["Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O", "A", "C", "noPosts", "noQues", "noAns", "z-score", "noComments", "sentiment_user_comments", "subjectivity_user_comments", "sentimentPolarity_Ans_post", "subjectivity_ans_posts", "time_diff_sec", "spell_comments_so", "typo_comments_so", "spell_posts", "typo_posts", "questionClarity_sentiment", "questionClarity_subjectivity", "answerQuality_sentiment", "answerQuality_subjectivity", "updownRatio", "f_ratio", "noProjects", "NoOfCommitComments", "noProjects_members" ]])   
df_std = std_scale.transform(df7[["Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O", "A", "C", "noPosts", "noQues", "noAns", "z-score", "noComments", "sentiment_user_comments", "subjectivity_user_comments", "sentimentPolarity_Ans_post", "subjectivity_ans_posts", "time_diff_sec", "spell_comments_so", "typo_comments_so", "spell_posts", "typo_posts", "questionClarity_sentiment", "questionClarity_subjectivity", "answerQuality_sentiment", "answerQuality_subjectivity", "updownRatio", "f_ratio", "noProjects", "NoOfCommitComments", "noProjects_members" ]])

minmax_scale = preprocessing.MinMaxScaler().fit(df7[["Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O", "A", "C", "noPosts", "noQues", "noAns", "z-score", "noComments", "sentiment_user_comments", "subjectivity_user_comments", "sentimentPolarity_Ans_post", "subjectivity_ans_posts", "time_diff_sec", "spell_comments_so", "typo_comments_so", "spell_posts", "typo_posts", "questionClarity_sentiment", "questionClarity_subjectivity", "answerQuality_sentiment", "answerQuality_subjectivity", "updownRatio", "f_ratio", "noProjects", "NoOfCommitComments", "noProjects_members" ]])
df_minmax = minmax_scale.transform(df7[["Upvotes", "Downvotes", "NoOfUpvotedAnswers", "NoOfDownvotedAnswers", "N", "E", "O", "A", "C", "noPosts", "noQues", "noAns", "z-score", "noComments", "sentiment_user_comments", "subjectivity_user_comments", "sentimentPolarity_Ans_post", "subjectivity_ans_posts", "time_diff_sec", "spell_comments_so", "typo_comments_so", "spell_posts", "typo_posts", "questionClarity_sentiment", "questionClarity_subjectivity", "answerQuality_sentiment", "answerQuality_subjectivity", "updownRatio", "f_ratio", "noProjects", "NoOfCommitComments", "noProjects_members" ]])

# %%
df_std
# Out:
# array([[ 3.59454653,  5.19047176,  0.62990505, ..., -0.09942379,
#          1.8497104 , -0.13567296],
#        [ 0.01050559,  0.07551099, -0.14194514, ..., -0.22441234,
#         -0.09355766, -0.26281809],
#        [ 0.47528837,  0.07551099, -0.01762028, ..., -0.09942379,
#         -0.09355766, -0.19924552],
#        ...,
#        [-0.16475856, -0.28984336, -0.17302636, ..., -0.25565947,
#         -0.09355766, -0.26281809],
#        [-0.16364929, -0.28984336, -0.17302636, ..., -0.25565947,
#         -0.09355766, -0.32639066],
#        [-0.16254002, -0.28984336, -0.16266595, ..., -0.13067093,
#         -0.09355766, -0.19924552]])

# %%
df_standard = pd.DataFrame(df_std)

# %%
df_standard1 = pd.DataFrame(df_std)

# %%
df_standard
# Out:
#              0          1         2          3         4         5         6   \
# 0      3.594547   5.190472  0.629905   0.272840 -0.393767  0.920941 -0.202359
# 1      0.010506   0.075511 -0.141945  -0.290071 -1.626114 -0.020160  1.217007
# 2      0.475288   0.075511 -0.017620   0.272840 -0.498524  1.033402 -0.296766
# 3      2.399866   3.729054  1.199727   2.665210 -0.277150  0.528444 -0.328816
# 4      0.446447   0.075511  0.029002  -0.290071 -0.491716 -0.737933  1.145276
# 5      7.211865   9.026692  6.048397   4.916853 -0.578172  0.164938  0.512426
# 6      2.240132   9.452939  2.013019  10.686687 -0.907598  0.577347  0.227593
# 7      0.361034   0.379973  0.236210  -0.008616 -0.929048  0.717046  0.317203
# 8      0.874624   6.895459  0.505580   6.464857 -0.188278  0.070716  0.308438
# 9      3.159714   3.729054  2.049281   0.835750 -0.325246  0.521116 -0.124305
# 10     0.662754   3.059238  0.158507   0.554295 -0.529710  0.375125  0.558779
# ...
